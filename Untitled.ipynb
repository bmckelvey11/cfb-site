# %%
import duckdb
import pandas as pd
import seaborn as sns

# %%
import sys; sys.path.insert(0, r"C:\Users\mckel\dev\cfb")
from cfb_paths import DB_PATH
conn = duckdb.connect(str(DB_PATH), read_only=True)

games = conn.sql("SELECT * from core.games")

games

# %%
import sys; sys.path.insert(0, r"C:\Users\mckel\dev\cfb")
from cfb_paths import DB_PATH
